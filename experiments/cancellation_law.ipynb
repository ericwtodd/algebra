# %%
import torch
import nnsight
from sympy.combinatorics import CyclicGroup, DihedralGroup
from src.load_utils import load_gpt, load_task

# %%
dirname = '../outputs/mixrosette-facts-10-16-8heads'
gpt = load_gpt(dirname).cuda()
task, task_name = load_task(dirname)
model = nnsight.NNsight(gpt)
# Out:
# number of parameters: 50.42M
# iteration: inf
# Trained on mixrosette up to order 10 with 16 symbols

# %% [markdown]
# #### Train the Closure/Elimination Subspaces

# %%
from src.closure import SubspaceExperimentConfig, run_subspace_optimization_experiment, run_subspace_sweep

# closure subspace
print("Closure Subspace (C Config)")
C_config = SubspaceExperimentConfig(layer=3, component='attn', num_directions=16, constraint_type="C",
                                  allow_identity_facts=False, allow_cf_identity_base_facts=False,
                                  batch_size=2000, num_shots=20, train_batch_size=256, n_steps=250,
                                  eval_interval=2, intervention_index=-1)
C_out = run_subspace_optimization_experiment(model, task, C_config)

# cancellation subspace
print("Cancellation Subspace (LUR Config)")
LUR_config = SubspaceExperimentConfig(layer=3, component='attn', num_directions=16, constraint_type="LUR",
                                  allow_identity_facts=False, allow_cf_identity_base_facts=False,
                                  batch_size=2000, num_shots=20, train_batch_size=256, n_steps=250,
                                  eval_interval=2, intervention_index=-1)
LUR_out = run_subspace_optimization_experiment(model, task, LUR_config)
# Out:
# Closure Subspace (C Config)
# Subspace Optimization: 100%|██████████| 251/251 [12:12<00:00,  2.92s/it, Loss=0.0031, Train Acc=1.0000, Val Acc=0.9990, Approx. Mask Sparsity=None]
# Cancellation Subspace (LUR Config)
# Subspace Optimization: 100%|██████████| 251/251 [12:14<00:00,  2.93s/it, Loss=0.0120, Train Acc=1.0000, Val Acc=0.9965, Approx. Mask Sparsity=None]

# %%
# closure subspace w/ identity=True
print("Closure Subspace (C Config + ID)")
C_config_idTRUE = SubspaceExperimentConfig(layer=3, component='attn', num_directions=16, constraint_type="C",
                                  allow_identity_facts=True, allow_cf_identity_base_facts=True,
                                  batch_size=2000, num_shots=20, train_batch_size=256, n_steps=250,
                                  eval_interval=2, intervention_index=-1)
C_out_idTRUE = run_subspace_optimization_experiment(model, task, C_config_idTRUE)

# cancellation subspace w/ identity=True
print("Cancellation Subspace (LUR Config + ID)")
LUR_config_idTRUE = SubspaceExperimentConfig(layer=3, component='attn', num_directions=16, constraint_type="LUR",
                                  allow_identity_facts=True, allow_cf_identity_base_facts=True,
                                  batch_size=2000, num_shots=20, train_batch_size=256, n_steps=250,
                                  eval_interval=2, intervention_index=-1)
LUR_out_idTRUE = run_subspace_optimization_experiment(model, task, LUR_config_idTRUE)
# Out:
# Closure Subspace (C Config + ID)
# Subspace Optimization: 100%|██████████| 251/251 [12:14<00:00,  2.93s/it, Loss=0.0242, Train Acc=1.0000, Val Acc=0.9740, Approx. Mask Sparsity=None]
# Cancellation Subspace (LUR Config + ID)
# Subspace Optimization: 100%|██████████| 251/251 [12:15<00:00,  2.93s/it, Loss=2.3628, Train Acc=0.5411, Val Acc=0.4925, Approx. Mask Sparsity=None]

# %%
import matplotlib.pyplot as plt

def plot_subspace_results(out, save_path=None):
    """
    Plot training loss and accuracy curves from experiment output.
    
    Args:
        out: Output dict from run_experiment()
        save_path: Optional path to save figure (e.g., 'results.pdf')
    
    Returns:
        fig, axes
    """
    results = out['results']
    config = out['config']
    
    # Set up publication-quality defaults
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
    plt.rcParams['font.size'] = 11
    plt.rcParams['axes.labelsize'] = 11
    plt.rcParams['axes.titlesize'] = 11
    plt.rcParams['xtick.labelsize'] = 10
    plt.rcParams['ytick.labelsize'] = 10
    plt.rcParams['legend.fontsize'] = 10
    plt.rcParams['figure.dpi'] = 300
    plt.rcParams['savefig.dpi'] = 300
    plt.rcParams['text.usetex'] = False  # Set to True if you have LaTeX installed
    plt.rcParams['axes.grid'] = True
    plt.rcParams['grid.alpha'] = 0.3
    plt.rcParams['grid.linewidth'] = 0.5
    
    fig, axes = plt.subplots(1, 2, figsize=(7, 2.5))
    
    # Colors
    color_loss = '#1f77b4'
    color_train = '#ff7f0e'
    color_val = '#2ca02c'
    
    # Plot 1: Loss
    ax1 = axes[0]
    steps = torch.arange(len(results['losses']))
    ax1.plot(steps, results['losses'], color=color_loss, linewidth=1.5, alpha=0.9)
    ax1.set_xlabel('Training Steps', fontweight='medium')
    ax1.set_ylabel('Loss', fontweight='medium')
    ax1.set_title('(a) Training Loss', fontweight='bold', pad=10)
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.set_xlim([0, len(results['losses'])-1])
    ax1.grid(True, alpha=0.3, linewidth=0.5)

    # Add minor ticks
    ax1.minorticks_on()
    ax1.tick_params(which='minor', length=2, width=0.5)
    ax1.tick_params(which='major', length=4, width=0.8)
    
    # Plot 2: Accuracy
    ax2 = axes[1]
    steps_train = torch.arange(len(results['train_accs']))
    steps_val = torch.arange(0, len(results['test_accs']) * config.eval_interval, config.eval_interval)
    
    ax2.plot(steps_train, results['train_accs'], color=color_train, 
             linewidth=1.5, label='Train', alpha=0.9)
    ax2.plot(steps_val, results['test_accs'], color=color_val, 
             linewidth=1.5, label='Validation', alpha=0.9, linestyle='--')
    
    ax2.set_xlabel('Training Steps', fontweight='medium')
    ax2.set_ylabel('Accuracy', fontweight='medium')
    ax2.set_title('(b) Subspace Intervention Accuracy', fontweight='bold', pad=10)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.legend(loc='lower right', frameon=True)
    ax2.grid(True, alpha=0.3, linewidth=0.5)
    
    for ax in axes:
        ax.set_facecolor('#f9f9f9')
    
    plt.tight_layout(pad=1.5)
    
    if save_path:
        fig.savefig(save_path, bbox_inches='tight', pad_inches=0.05)
        print(f"Saved to {save_path}")
    
    plt.show()
    
    return fig, axes

plot_subspace_results(C_out)
# Out:
# (<Figure size 2100x750 with 2 Axes>,
#  array([<Axes: title={'center': '(a) Training Loss'}, xlabel='Training Steps', ylabel='Loss'>,
#         <Axes: title={'center': '(b) Subspace Intervention Accuracy'}, xlabel='Training Steps', ylabel='Accuracy'>],
#        dtype=object))

# %%
# Set up publication-quality defaults
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['font.size'] = 11
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 11
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['text.usetex'] = False
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3
plt.rcParams['grid.linewidth'] = 0.5

# Colors
colors = {
    'A_val': '#1f77b4',  # blue
    'B_val': '#d62728',  # red
}
labels = {'A': 'Exclude Identity Facts', 'B': 'Include Identity Facts'}

fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Data for both plots
plot_data = [
    (C_out_idTRUE, C_out, '(a) Closure Subspace (d=16)'),
    (LUR_out_idTRUE, LUR_out, '(b) Elimination Subspace (d=16)'),
]

for ax, (out, out_alternate, title) in zip(axes, plot_data):
    results = out['results']
    config = out['config']
    results_alt = out_alternate['results']
    config_alt = out_alternate['config']

    steps_val = torch.arange(0, len(results['test_accs']) * config.eval_interval, config.eval_interval)
    steps_val_alt = torch.arange(0, len(results_alt['test_accs']) * config_alt.eval_interval, config_alt.eval_interval)

    
    ax.plot(steps_val_alt, results_alt['test_accs'], color=colors['A_val'], 
            linewidth=1.5, alpha=0.9, label=labels['A'])
    ax.plot(steps_val, results['test_accs'], color=colors['B_val'], 
            linewidth=1.5, alpha=0.9, label=labels['B'])
    
    ax.set_title(title, fontweight='bold', pad=10)
    ax.set_xlabel('Training Steps', fontweight='medium')
    ax.set_ylabel('Val. Intervention Accuracy', fontweight='medium')
    ax.set_ylim([0, 1.05])
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(True, alpha=0.3, linewidth=0.5)
    ax.set_facecolor('#f9f9f9')

# Add horizontal line only for LUR plot
axes[0].axhline(1 - 0.287, color='black', linestyle=':', linewidth=1, alpha=0.7, label='% Non-Identity Facts')
axes[1].axhline(1 - 0.287, color='black', linestyle=':', linewidth=1, alpha=0.7, label='% Non-Identity Facts')


# Get handles and labels from first axis for joint legend
handles, legend_labels = axes[0].get_legend_handles_labels()
fig.legend(handles, legend_labels, loc='lower center', ncol=3, frameon=True, fontsize=9, bbox_to_anchor=(0.5, -0.05))

plt.tight_layout(pad=1.5)
plt.subplots_adjust(bottom=0.22)
# fig.savefig('subspace_training_results.pdf', bbox_inches='tight', pad_inches=0.05)
plt.show()

# %% [markdown]
# #### Sweep Over Closure Subspace Dimension

# %%
from src.closure import SubspaceExperimentConfig, run_subspace_sweep

test_sweep_configs = [
    SubspaceExperimentConfig(layer=L, component='attn', num_directions=D, constraint_type="C",
                             allow_identity_facts=False, allow_cf_identity_base_facts=False,
                             batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                             eval_interval=2, intervention_index=-1)
     for L in [0,1,2,3] for D in [2,4,6,8,10,12,16,20,24,32]
]
dimension_layer_sweep_results = run_subspace_sweep(model, task, test_sweep_configs)
# Out:
# Subspace Optimization: 100%|██████████| 51/51 [03:14<00:00,  3.82s/it, Loss=7.6744, Train Acc=0.0005, Val Acc=0.0005, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03
Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:19<00:00,  2.74s/it, Loss=4.0542, Train Acc=0.0811, Val Acc=0.0685, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:20<00:00,  2.76s/it, Loss=2.1227, Train Acc=0.3071, Val Acc=0.3015, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:23<00:00,  2.81s/it, Loss=1.0396, Train Acc=0.6131, Val Acc=0.5305, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:23<00:00,  2.82s/it, Loss=0.5045, Train Acc=0.8443, Val Acc=0.7645, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:25<00:00,  2.85s/it, Loss=0.1995, Train Acc=0.9746, Val Acc=0.8760, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:26<00:00,  2.88s/it, Loss=0.0655, Train Acc=0.9984, Val Acc=0.9460, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:29<00:00,  2.92s/it, Loss=0.0106, Train Acc=1.0000, Val Acc=0.9905, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:31<00:00,  2.97s/it, Loss=0.0031, Train Acc=1.0000, Val Acc=1.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:32<00:00,  3.00s/it, Loss=0.0035, Train Acc=1.0000, Val Acc=0.9990, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:35<00:00,  3.05s/it, Loss=0.0040, Train Acc=1.0000, Val Acc=0.9995, Approx. Mask Sparsity=None]

# %%
test_sweep_configs_block = [
    SubspaceExperimentConfig(layer=L, component='block', num_directions=D, constraint_type="C",
                             allow_identity_facts=False, allow_cf_identity_base_facts=False,
                             batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                             eval_interval=2, intervention_index=-1)
     for L in [0,1,2,3] for D in [2,4,6,8,10,12,16,20,24,32]
]
dimension_layer_sweep_results_block = run_subspace_sweep(model, task, test_sweep_configs_block)

test_sweep_configs_mlp = [
    SubspaceExperimentConfig(layer=L, component='mlp', num_directions=D, constraint_type="C",
                             allow_identity_facts=False, allow_cf_identity_base_facts=False,
                             batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                             eval_interval=2, intervention_index=-1)
     for L in [0,1,2,3] for D in [2,4,6,8,10,12,16,20,24,32]
]
dimension_layer_sweep_results_mlp = run_subspace_sweep(model, task, test_sweep_configs_mlp)
# Out:
# Subspace Optimization: 100%|██████████| 51/51 [03:06<00:00,  3.67s/it, Loss=7.9946, Train Acc=0.0000, Val Acc=0.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:10<00:00,  3.74s/it, Loss=7.1123, Train Acc=0.0000, Val Acc=0.0015, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:11<00:00,  3.75s/it, Loss=6.2956, Train Acc=0.0059, Val Acc=0.0030, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:13<00:00,  3.79s/it, Loss=5.6893, Train Acc=0.0073, Val Acc=0.0065, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:15<00:00,  3.83s/it, Loss=5.1903, Train Acc=0.0207, Val Acc=0.0155, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:16<00:00,  3.84s/it, Loss=4.6265, Train Acc=0.0305, Val Acc=0.0335, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:18<00:00,  3.90s/it, Loss=4.0993, Train Acc=0.0521, Val Acc=0.0465, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:21<00:00,  3.94s/it, Loss=4.1680, Train Acc=0.0555, Val Acc=0.0565, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:22<00:00,  3.97s/it, Loss=4.1094, Train Acc=0.0595, Val Acc=0.0550, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:27<00:00,  4.07s/it, Loss=4.0519, Train Acc=0.0593, Val Acc=0.0680, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:46<00:00,  3.26s/it, Loss=6.5492, Train Acc=0.0105, Val Acc=0.0055, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02
Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:15<00:00,  2.65s/it, Loss=5.0785, Train Acc=0.0372, Val Acc=0.0300, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:17<00:00,  2.70s/it, Loss=4.5929, Train Acc=0.0378, Val Acc=0.0275, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:18<00:00,  2.71s/it, Loss=3.7870, Train Acc=0.0636, Val Acc=0.0435, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:20<00:00,  2.75s/it, Loss=3.7157, Train Acc=0.0536, Val Acc=0.0390, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:22<00:00,  2.79s/it, Loss=3.6557, Train Acc=0.0634, Val Acc=0.0425, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:25<00:00,  2.86s/it, Loss=3.5316, Train Acc=0.0558, Val Acc=0.0390, Approx. Mask Sparsity=None]

# %%
fig, ax = plt.subplots(figsize=(8, 4))

A = torch.tensor([out['results']['test_accs'][-1] for out in dimension_layer_sweep_results]).reshape(4,10)
B = torch.tensor([out['results']['test_accs'][-1] for out in dimension_layer_sweep_results_mlp]).reshape(4,10)
C = torch.tensor([out['results']['test_accs'][-1] for out in dimension_layer_sweep_results_block]).reshape(4,10)
data = torch.stack([A, B, C], dim=1).reshape(-1, 10)


im = ax.imshow(data, cmap='Blues', aspect='auto')

# Add colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Intervention Accuracy', fontweight='medium', fontsize=12)
cbar.ax.tick_params(labelsize=12)

# Add text annotations
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        val = data[i, j]
        # White text on dark cells, black on light
        color = 'black' if val < 0.5 * (data.max() + data.min()) else 'white'
        ax.text(j, i, f'{val:.2f}', ha='center', va='center', 
                color=color, fontsize=11)


ax.set_xticks(torch.arange(10), [2,4,6,8,10,12,16,20,24,32], fontsize=12)
ax.set_yticks(torch.arange(12), ['L0 Attn', 'L0 MLP', 'L0 Block', 'L1 Attn', 'L1 MLP', 'L1 Block', 'L2 Attn', 'L2 MLP', 'L2 Block', 'L3 Attn', 'L3 MLP', 'L3 Block'], fontsize=12)

ax.set_xlabel('Subspace Dimension', fontweight='medium', fontsize=12)
# ax.set_ylabel('Attention Layer', fontweight='medium')
# ax.set_title('Validation Accuracy by Configuration', fontweight='bold', pad=10)

ax.grid(False)

plt.tight_layout()
# plt.savefig('closure_subspace_dim_sweep.pdf', bbox_inches='tight', pad_inches=0.05)
plt.show()

# %% [markdown]
# #### Sweep Over Elimination Subspace Location and Dimension

# %%
from src.closure import SubspaceExperimentConfig, run_subspace_optimization_experiment, run_subspace_sweep
C_config = SubspaceExperimentConfig(layer=3, component='attn', num_directions=16, constraint_type="C",
                                  allow_identity_facts=False, allow_cf_identity_base_facts=False,
                                  batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                                  eval_interval=2, intervention_index=-1)
C_out = run_subspace_optimization_experiment(model, task, C_config)
# Out:
# Subspace Optimization: 100%|██████████| 51/51 [02:32<00:00,  2.99s/it, Loss=0.0044, Train Acc=1.0000, Val Acc=1.0000, Approx. Mask Sparsity=None]

# %%
from src.closure import SubspaceExperimentConfig, run_subspace_sweep

LUR_test_sweep_configs_attn = [
    SubspaceExperimentConfig(layer=L, component='attn', num_directions=D, constraint_type="C",
                             allow_identity_facts=False, allow_cf_identity_base_facts=False,
                             batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                             eval_interval=2, intervention_index=-1)
     for L in [0,1,2,3] for D in [2,4,6,8,10,12,16,20,24,32]
]
LUR_dimension_layer_sweep_results_attn = run_subspace_sweep(model, task, LUR_test_sweep_configs_attn)

LUR_test_sweep_configs_block = [
    SubspaceExperimentConfig(layer=L, component='block', num_directions=D, constraint_type="LUR",
                             allow_identity_facts=False, allow_cf_identity_base_facts=False,
                             batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                             eval_interval=2, intervention_index=-1)
     for L in [0,1,2,3] for D in [2,4,6,8,10,12,16,20,24,32]
]
LUR_dimension_layer_sweep_results_block = run_subspace_sweep(model, task, LUR_test_sweep_configs_block)

LUR_test_sweep_configs_mlp = [
    SubspaceExperimentConfig(layer=L, component='mlp', num_directions=D, constraint_type="LUR",
                             allow_identity_facts=False, allow_cf_identity_base_facts=False,
                             batch_size=2000, num_shots=20, train_batch_size=256, n_steps=50,
                             eval_interval=2, intervention_index=-1)
     for L in [0,1,2,3] for D in [2,4,6,8,10,12,16,20,24,32]
]
LUR_dimension_layer_sweep_results_mlp = run_subspace_sweep(model, task, LUR_test_sweep_configs_mlp)
# Out:
# Subspace Optimization: 100%|██████████| 51/51 [03:17<00:00,  3.88s/it, Loss=7.7151, Train Acc=0.0011, Val Acc=0.0005, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:19<00:00,  3.92s/it, Loss=6.7062, Train Acc=0.0075, Val Acc=0.0040, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:20<00:00,  3.93s/it, Loss=5.7685, Train Acc=0.0110, Val Acc=0.0080, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:21<00:00,  3.96s/it, Loss=5.0529, Train Acc=0.0273, Val Acc=0.0295, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:24<00:00,  4.00s/it, Loss=4.3433, Train Acc=0.0496, Val Acc=0.0420, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:25<00:00,  4.03s/it, Loss=3.9216, Train Acc=0.0767, Val Acc=0.0725, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:27<00:00,  4.07s/it, Loss=3.2422, Train Acc=0.1310, Val Acc=0.1310, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:30<00:00,  4.13s/it, Loss=3.1646, Train Acc=0.1369, Val Acc=0.1295, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:32<00:00,  4.16s/it, Loss=3.2762, Train Acc=0.1333, Val Acc=0.1315, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:36<00:00,  4.25s/it, Loss=3.1660, Train Acc=0.1493, Val Acc=0.1375, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:56<00:00,  3.47s/it, Loss=7.1480, Train Acc=0.0034, Val Acc=0.0025, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:58<00:00,  3.49s/it, Loss=6.2242, Train Acc=0.0109, Val Acc=0.0105, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:59<00:00,  3.52s/it, Loss=5.4637, Train Acc=0.0400, Val Acc=0.0265, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:01<00:00,  3.55s/it, Loss=4.7129, Train Acc=0.0754, Val Acc=0.0510, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:02<00:00,  3.58s/it, Loss=4.5378, Train Acc=0.0719, Val Acc=0.0635, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:04<00:00,  3.61s/it, Loss=3.8261, Train Acc=0.1558, Val Acc=0.1090, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:06<00:00,  3.66s/it, Loss=3.6766, Train Acc=0.1689, Val Acc=0.1320, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:09<00:00,  3.71s/it, Loss=3.3871, Train Acc=0.1955, Val Acc=0.1650, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:11<00:00,  3.76s/it, Loss=3.2798, Train Acc=0.2136, Val Acc=0.1630, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:14<00:00,  3.82s/it, Loss=2.9243, Train Acc=0.2237, Val Acc=0.1745, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:35<00:00,  3.05s/it, Loss=6.5892, Train Acc=0.0156, Val Acc=0.0065, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:36<00:00,  3.07s/it, Loss=5.6164, Train Acc=0.0261, Val Acc=0.0125, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:37<00:00,  3.10s/it, Loss=4.7746, Train Acc=0.0545, Val Acc=0.0430, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:39<00:00,  3.14s/it, Loss=4.1841, Train Acc=0.0736, Val Acc=0.0680, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:41<00:00,  3.16s/it, Loss=3.7074, Train Acc=0.1111, Val Acc=0.0950, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:42<00:00,  3.19s/it, Loss=3.1551, Train Acc=0.1715, Val Acc=0.1245, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:45<00:00,  3.24s/it, Loss=2.4963, Train Acc=0.2362, Val Acc=0.2060, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:47<00:00,  3.29s/it, Loss=2.1872, Train Acc=0.2679, Val Acc=0.2110, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:49<00:00,  3.33s/it, Loss=1.8442, Train Acc=0.3465, Val Acc=0.2705, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:53<00:00,  3.40s/it, Loss=1.7857, Train Acc=0.3502, Val Acc=0.2845, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:18<00:00,  2.72s/it, Loss=4.1436, Train Acc=0.0770, Val Acc=0.0630, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:20<00:00,  2.75s/it, Loss=2.0536, Train Acc=0.3176, Val Acc=0.2915, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:21<00:00,  2.78s/it, Loss=1.0189, Train Acc=0.6419, Val Acc=0.5695, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:23<00:00,  2.81s/it, Loss=0.5117, Train Acc=0.8446, Val Acc=0.7650, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:24<00:00,  2.84s/it, Loss=0.1914, Train Acc=0.9760, Val Acc=0.8760, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:26<00:00,  2.86s/it, Loss=0.1123, Train Acc=0.9941, Val Acc=0.9235, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:28<00:00,  2.90s/it, Loss=0.0116, Train Acc=1.0000, Val Acc=0.9960, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:30<00:00,  2.95s/it, Loss=0.0033, Train Acc=1.0000, Val Acc=0.9985, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:32<00:00,  2.98s/it, Loss=0.0036, Train Acc=1.0000, Val Acc=0.9975, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:34<00:00,  3.04s/it, Loss=0.0035, Train Acc=1.0000, Val Acc=0.9990, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:06<00:00,  3.66s/it, Loss=12.4286, Train Acc=0.0000, Val Acc=0.0005, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:07<00:00,  3.68s/it, Loss=11.9199, Train Acc=0.0015, Val Acc=0.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:08<00:00,  3.70s/it, Loss=11.5949, Train Acc=0.0005, Val Acc=0.0005, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:10<00:00,  3.73s/it, Loss=11.1375, Train Acc=0.0034, Val Acc=0.0035, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:12<00:00,  3.77s/it, Loss=10.7784, Train Acc=0.0010, Val Acc=0.0015, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:17<00:00,  3.87s/it, Loss=10.6428, Train Acc=0.0015, Val Acc=0.0010, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:17<00:00,  3.87s/it, Loss=10.3054, Train Acc=0.0045, Val Acc=0.0035, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:19<00:00,  3.92s/it, Loss=10.1178, Train Acc=0.0030, Val Acc=0.0010, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:23<00:00,  4.00s/it, Loss=10.2000, Train Acc=0.0035, Val Acc=0.0045, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:26<00:00,  4.06s/it, Loss=10.1132, Train Acc=0.0024, Val Acc=0.0035, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:49<00:00,  3.32s/it, Loss=8.0856, Train Acc=0.0362, Val Acc=0.0360, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:49<00:00,  3.32s/it, Loss=6.3818, Train Acc=0.0780, Val Acc=0.0750, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:52<00:00,  3.38s/it, Loss=5.4395, Train Acc=0.0848, Val Acc=0.0715, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:52<00:00,  3.39s/it, Loss=4.1837, Train Acc=0.1834, Val Acc=0.1190, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:52<00:00,  3.39s/it, Loss=3.9179, Train Acc=0.1877, Val Acc=0.1305, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:54<00:00,  3.43s/it, Loss=3.5876, Train Acc=0.2250, Val Acc=0.1560, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:57<00:00,  3.48s/it, Loss=3.3563, Train Acc=0.2418, Val Acc=0.1655, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:00<00:00,  3.53s/it, Loss=3.0845, Train Acc=0.2989, Val Acc=0.1820, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:02<00:00,  3.58s/it, Loss=2.7954, Train Acc=0.3385, Val Acc=0.2130, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:05<00:00,  3.63s/it, Loss=2.5650, Train Acc=0.3625, Val Acc=0.2030, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:29<00:00,  2.93s/it, Loss=7.6907, Train Acc=0.0175, Val Acc=0.0215, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:29<00:00,  2.94s/it, Loss=5.5488, Train Acc=0.0829, Val Acc=0.0630, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:31<00:00,  2.97s/it, Loss=4.9010, Train Acc=0.1076, Val Acc=0.0975, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:33<00:00,  3.01s/it, Loss=3.6423, Train Acc=0.1952, Val Acc=0.1525, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:35<00:00,  3.05s/it, Loss=3.4560, Train Acc=0.2225, Val Acc=0.1590, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:36<00:00,  3.08s/it, Loss=2.9823, Train Acc=0.2913, Val Acc=0.2085, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:38<00:00,  3.10s/it, Loss=2.1731, Train Acc=0.4043, Val Acc=0.2360, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:39<00:00,  3.12s/it, Loss=1.8459, Train Acc=0.4980, Val Acc=0.2895, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:40<00:00,  3.16s/it, Loss=1.2856, Train Acc=0.6237, Val Acc=0.3800, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:43<00:00,  3.21s/it, Loss=0.9068, Train Acc=0.7460, Val Acc=0.4370, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:09<00:00,  2.54s/it, Loss=10.6667, Train Acc=0.0010, Val Acc=0.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:10<00:00,  2.56s/it, Loss=9.1726, Train Acc=0.0089, Val Acc=0.0075, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:11<00:00,  2.58s/it, Loss=7.8289, Train Acc=0.0115, Val Acc=0.0110, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:12<00:00,  2.60s/it, Loss=7.0371, Train Acc=0.0193, Val Acc=0.0085, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:13<00:00,  2.62s/it, Loss=6.4254, Train Acc=0.0188, Val Acc=0.0130, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:15<00:00,  2.66s/it, Loss=5.8757, Train Acc=0.0184, Val Acc=0.0155, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:17<00:00,  2.69s/it, Loss=5.0999, Train Acc=0.0121, Val Acc=0.0115, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:19<00:00,  2.73s/it, Loss=5.0458, Train Acc=0.0130, Val Acc=0.0070, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:20<00:00,  2.76s/it, Loss=5.0949, Train Acc=0.0032, Val Acc=0.0060, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:24<00:00,  2.83s/it, Loss=5.0647, Train Acc=0.0035, Val Acc=0.0040, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:07<00:00,  3.68s/it, Loss=12.2672, Train Acc=0.0005, Val Acc=0.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:07<00:00,  3.68s/it, Loss=12.1323, Train Acc=0.0005, Val Acc=0.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:09<00:00,  3.72s/it, Loss=11.7789, Train Acc=0.0000, Val Acc=0.0005, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:10<00:00,  3.74s/it, Loss=11.3984, Train Acc=0.0000, Val Acc=0.0020, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:12<00:00,  3.77s/it, Loss=11.1575, Train Acc=0.0015, Val Acc=0.0000, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:13<00:00,  3.80s/it, Loss=10.9103, Train Acc=0.0010, Val Acc=0.0010, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:16<00:00,  3.85s/it, Loss=10.8190, Train Acc=0.0016, Val Acc=0.0010, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:18<00:00,  3.89s/it, Loss=10.5845, Train Acc=0.0015, Val Acc=0.0025, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:20<00:00,  3.93s/it, Loss=10.5728, Train Acc=0.0029, Val Acc=0.0020, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:24<00:00,  4.00s/it, Loss=10.5922, Train Acc=0.0024, Val Acc=0.0010, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:46<00:00,  3.26s/it, Loss=10.6915, Train Acc=0.0174, Val Acc=0.0165, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:46<00:00,  3.27s/it, Loss=9.1640, Train Acc=0.0284, Val Acc=0.0165, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:48<00:00,  3.30s/it, Loss=8.3599, Train Acc=0.0302, Val Acc=0.0300, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:50<00:00,  3.34s/it, Loss=7.5596, Train Acc=0.0453, Val Acc=0.0275, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:51<00:00,  3.37s/it, Loss=7.0266, Train Acc=0.0436, Val Acc=0.0345, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:52<00:00,  3.38s/it, Loss=6.2929, Train Acc=0.0663, Val Acc=0.0560, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:55<00:00,  3.44s/it, Loss=5.3714, Train Acc=0.0982, Val Acc=0.0710, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:57<00:00,  3.48s/it, Loss=5.2488, Train Acc=0.1020, Val Acc=0.0845, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:00<00:00,  3.53s/it, Loss=4.9165, Train Acc=0.1118, Val Acc=0.0885, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [03:03<00:00,  3.60s/it, Loss=4.7489, Train Acc=0.1359, Val Acc=0.0870, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:27<00:00,  2.89s/it, Loss=9.2853, Train Acc=0.0095, Val Acc=0.0120, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:28<00:00,  2.91s/it, Loss=8.2041, Train Acc=0.0146, Val Acc=0.0110, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:30<00:00,  2.94s/it, Loss=8.0233, Train Acc=0.0305, Val Acc=0.0340, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:32<00:00,  2.98s/it, Loss=6.7827, Train Acc=0.0510, Val Acc=0.0315, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:33<00:00,  3.00s/it, Loss=6.3287, Train Acc=0.0536, Val Acc=0.0355, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:35<00:00,  3.04s/it, Loss=5.3563, Train Acc=0.0804, Val Acc=0.0645, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:36<00:00,  3.07s/it, Loss=4.8993, Train Acc=0.1215, Val Acc=0.0825, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:39<00:00,  3.12s/it, Loss=4.4217, Train Acc=0.1448, Val Acc=0.0945, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:41<00:00,  3.17s/it, Loss=4.1035, Train Acc=0.1750, Val Acc=0.1205, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:43<00:00,  3.21s/it, Loss=3.8553, Train Acc=0.1887, Val Acc=0.1320, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:09<00:00,  2.54s/it, Loss=10.5225, Train Acc=0.0034, Val Acc=0.0035, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:10<00:00,  2.56s/it, Loss=9.0039, Train Acc=0.0115, Val Acc=0.0090, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:11<00:00,  2.57s/it, Loss=7.5027, Train Acc=0.0239, Val Acc=0.0160, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:12<00:00,  2.60s/it, Loss=6.2731, Train Acc=0.0448, Val Acc=0.0290, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:14<00:00,  2.63s/it, Loss=5.2417, Train Acc=0.0719, Val Acc=0.0620, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:15<00:00,  2.66s/it, Loss=4.0405, Train Acc=0.1088, Val Acc=0.0870, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:17<00:00,  2.69s/it, Loss=2.7608, Train Acc=0.1790, Val Acc=0.1350, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:19<00:00,  2.74s/it, Loss=2.7876, Train Acc=0.1658, Val Acc=0.1370, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:20<00:00,  2.76s/it, Loss=2.6242, Train Acc=0.1630, Val Acc=0.1325, Approx. Mask Sparsity=None]
# Subspace Optimization: 100%|██████████| 51/51 [02:24<00:00,  2.83s/it, Loss=2.7328, Train Acc=0.1610, Val Acc=0.1290, Approx. Mask Sparsity=None]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['font.size'] = 11
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 11
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['text.usetex'] = False
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3
plt.rcParams['grid.linewidth'] = 0.5

fig, ax = plt.subplots(figsize=(8, 4))

A = torch.tensor([out['results']['test_accs'][-1] for out in LUR_dimension_layer_sweep_results_attn]).reshape(4,10)
B = torch.tensor([out['results']['test_accs'][-1] for out in LUR_dimension_layer_sweep_results_mlp]).reshape(4,10)
C = torch.tensor([out['results']['test_accs'][-1] for out in LUR_dimension_layer_sweep_results_block]).reshape(4,10)
data = torch.stack([A, B, C], dim=1).reshape(-1, 10)


im = ax.imshow(data, cmap='BuPu', aspect='auto')

# Add colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Intervention Accuracy', fontweight='medium', fontsize=12)
cbar.ax.tick_params(labelsize=12)

# Add text annotations
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        val = data[i, j]
        # White text on dark cells, black on light
        color = 'black' if val < 0.5 * (data.max() + data.min()) else 'white'
        ax.text(j, i, f'{val:.2f}', ha='center', va='center', 
                color=color, fontsize=11)


ax.set_xticks(torch.arange(10), [2,4,6,8,10,12,16,20,24,32], fontsize=12)
ax.set_yticks(torch.arange(12), ['L0 Attn', 'L0 MLP', 'L0 Block', 'L1 Attn', 'L1 MLP', 'L1 Block', 'L2 Attn', 'L2 MLP', 'L2 Block', 'L3 Attn', 'L3 MLP', 'L3 Block'], fontsize=12)

ax.set_xlabel('Subspace Dimension', fontweight='medium', fontsize=12)
# ax.set_ylabel('Attention Layer', fontweight='medium')
# ax.set_title('Validation Accuracy by Configuration', fontweight='bold', pad=10)

ax.grid(False)

plt.tight_layout()
# plt.savefig('elimination_subspace_dim_sweep.pdf', bbox_inches='tight', pad_inches=0.05)
plt.show()
